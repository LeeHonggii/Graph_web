# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "한국의 수도는?"
        }
    ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='한국의 수도는 서울입니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None)

# %%
import pdfplumber
pdf = pdfplumber.open(r"C:\Users\userpc\Desktop\oneday\Graph_web\ADsP.pdf")

# %%
p0 = pdf.pages[0]
im = p0.to_image()
im

# %%
print(pdf.pages[1].extract_text())
# Out:
# 빅데이터 분석 기법과 방법론 확대 -> 인문학 열풍과 무관하다
# 데이터 사이언티스트 필요역량 -> 하드스킬(전문지식 및 기술) + 소프트스킬(스토리텔링, 통찰
# 력, 커뮤니케이션)
# cf. 네트워크 최적화는 필요역량이 아니다.
# 데이터사이언스 -> 주로 통찰력있는 분석에 초점을 둔다 (정확성에 초점 x)
# (단답형)
# SQL문에서 -> WHERE ~~ BETWEEN ~~~~ AND ~~~~
# 데이터사이언티스트 필요역량 -> 하드스킬, 소프트스킬
# 지식을 도출하기 위한 재료 -> 정보
# 기업의 의사결정 지원, 통합적이며 시간성을 가지는 비휘발성 데이터집합 -> 데이터 웨어하우
# 스
# 정제되지 않은 자연스러운 상태의 아주 큰 데이터세트 -> 데이터 레이크
# 수치로 명확하게 표현되는 데이터 -> 정량적 데이터
# 기업이 외부공급업체(제휴업체)와 통합된 정보시스템 구축 -> SCM
# 페이스북 위에서 작동하는 앱 만들기 시작, 하둡 -> 플랫폼
# 생명의 진화를 모방한 알고리즘, 최적화하는 해답을 얻기 위한 알고리즘 -> 유전자 알고리즘
# -2과목-
# (객관식)
# 성공적인 분석을 위해 고려해야하는 요소 -> 관련 데이터 파악, 원점에서 솔루션 탐색, 이행
# 저해 요소 관리 (비즈니스 케이스 확보 x)
# 정형 데이터 -> ERP, CRM, SCM 등 정보시스템
# 반정형 데이터 -> 로그데이터, 모바일데이터, 센싱데이터(센서)
# 비정형 데이터 -> 영상, 음성 문자, 이메일
# CRISP-DM 방법론에서 모델링 단계에서 수행하는 것 -> 모델링 기법 선택, 모델 테스트 계

# %%
import pdfplumber
pdf = pdfplumber.open(r"C:\Users\userpc\Desktop\oneday\Graph_web\ADsP.pdf")

metadata = {}
for page_number, page in enumerate(pdf.pages):
    text = page.extract_text()
    # 문장을 엔터 단위로 먼저 나누고, 빈 줄 제거
    sentences = [sentence.strip() for sentence in text.split('\n') if sentence.strip()]
    # 문장에 번호 매기기
    numbered_sentences = {f"sentence_{i+1}": sentence for i, sentence in enumerate(sentences)}
    metadata[f"page_{page_number+1}"] = numbered_sentences

# 결과 확인 (더 보기 좋게 출력)
print("=== 첫 페이지 문장들 ===")
for sentence_num, sentence in metadata['page_1'].items():
    print(f"\n{sentence_num}:")
    print(sentence)
# Out:
# === 첫 페이지 문장들 ===
#
# sentence_1:
# <ADsP 요약정리 및 오답노트>
#
# sentence_2:
# -1과목-
#
# sentence_3:
# (객관식)
#
# sentence_4:
# 데이터 마스킹 : 데이터의 속성은 유지한 채, 익명으로 생성
#
# sentence_5:
# Cinematch -> 넷플릭스에서 개발한 알고리즘
#
# sentence_6:
# 데이터마이닝 vs 머신러닝(딥러닝) 구분하기 다른거임
#
# sentence_7:
# 트레이딩, 공급, 수요예측 -> 에너지 산업
#
# sentence_8:
# CRM -> 고객관계관리 데이터베이스 (기업내부)
#
# sentence_9:
# ERP -> 기업 전체를 통합적으로 관리하고 경영의 효율화 목적
#
# sentence_10:
# 빅데이터 가치측정 어려윤 이유 : 1) 데이터 재사용,재조합,다목적용 개발
#
# sentence_11:
# 2) 새로운 가치 창출
#
# sentence_12:
# 3) 분석 기술 발전
#
# sentence_13:
# cf. 전문인력증가는 가치측정과 관련 없음
#
# sentence_14:
# 사생활 침해를 막기 위한 개인정보 무작위 처리 (본래 목적 외에 사용 방지기술) -> 난수화
#
# sentence_15:
# 유형분석 -> 특성에따라 분류할때 사용한다.
#
# sentence_16:
# 핀테크(금융)분야에서 빅데이터 활용의 핵심분야 -> 신용평가
#
# sentence_17:
# K-NN 분석기법 - 딥러닝과 관련 x
#
# sentence_18:
# LSTM, Autoencoder, RNN -> 딥러닝과 관련 o
#
# sentence_19:
# Caffe, Tnsorflow, Theano -> 딥러닝 관련된 오픈소스
#
# sentence_20:
# Anaconda -> 머신러닝 관련된 오픈소스
#
# sentence_21:
# ...

# %%
from PyPDF2 import PdfReader

# PDF 파일 열기
reader = PdfReader(r"C:\Users\userpc\Desktop\oneday\Graph_web\ADsP.pdf")

metadata = {}
# 페이지별로 처리
for page_number, page in enumerate(reader.pages):
    # 텍스트 추출
    text = page.extract_text()
    # 문장을 엔터 단위로 나누고, 빈 줄 제거
    sentences = [sentence.strip() for sentence in text.split('\n') if sentence.strip()]
    # 문장에 번호 매기기
    numbered_sentences = {f"sentence_{i+1}": sentence for i, sentence in enumerate(sentences)}
    metadata[f"page_{page_number+1}"] = numbered_sentences

# 결과 확인
print("=== 첫 페이지 문장들 ===")
for sentence_num, sentence in metadata['page_1'].items():
    print(f"\n{sentence_num}:")
    print(sentence)
# Out:
# === 첫 페이지 문장들 ===
#
# sentence_1:
# <ADsP 요약정리 및 오답노트 >
#
# sentence_2:
# -1과목-
#
# sentence_3:
# (객관식 )
#
# sentence_4:
# 데이터 마스킹 : 데이터의 속성은 유지한 채, 익명으로 생성
#
# sentence_5:
# Cinematch -> 넷플릭스에서 개발한 알고리즘
#
# sentence_6:
# 데이터마이닝 vs 머신러닝 (딥러닝 ) 구분하기 다른거임
#
# sentence_7:
# 트레이딩 , 공급, 수요예측 -> 에너지 산업
#
# sentence_8:
# CRM -> 고객관계관리 데이터베이스 (기업내부 )
#
# sentence_9:
# ERP -> 기업 전체를 통합적으로 관리하고 경영의 효율화 목적
#
# sentence_10:
# 빅데이터 가치측정 어려윤 이유 : 1) 데이터 재사용 ,재조합 ,다목적용 개발
#
# sentence_11:
# 2) 새로운 가치 창출
#
# sentence_12:
# 3) 분석 기술 발전
#
# sentence_13:
# cf. 전문인력증가는 가치측정과 관련 없음
#
# sentence_14:
# 사생활 침해를 막기 위한 개인정보 무작위 처리 (본래 목적 외에 사용 방지기술 ) -> 난수화
#
# sentence_15:
# 유형분석 -> 특성에따라 분류할때 사용한다 .
#
# sentence_16:
# 핀테크 (금융)분야에서 빅데이터 활용의 핵심분야 -> 신용평가
#
# sentence_17:
# K-NN 분석기법 - 딥러닝과 관련 x
#
# sentence_18:
# LSTM, Autoencoder, RNN -> 딥러닝과 관련 o
#
# sentence_19:
# Caffe, Tnsorflow, Theano -> 딥러닝 관련된 오픈소스
#
# sentence_20:
# Anaconda -> 머신러닝 관련된 오픈소스
#
# sentence_21:
# ...

# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer

# PDF 파일 경로
pdf_path = r"C:\Users\userpc\Desktop\oneday\Graph_web\ADsP.pdf"

metadata = {}
# 페이지별로 처리
for page_number, page_layout in enumerate(extract_pages(pdf_path)):
    # 페이지의 텍스트 추출
    texts = []
    for element in page_layout:
        if isinstance(element, LTTextContainer):
            texts.append(element.get_text())
    
    # 전체 텍스트 합치기
    text = ''.join(texts)
    
    # 문장을 엔터 단위로 나누고, 빈 줄 제거
    sentences = [sentence.strip() for sentence in text.split('\n') if sentence.strip()]
    
    # 문장에 번호 매기기
    numbered_sentences = {f"sentence_{i+1}": sentence for i, sentence in enumerate(sentences)}
    metadata[f"page_{page_number+1}"] = numbered_sentences

# 결과 확인
print("=== 첫 페이지 문장들 ===")
for sentence_num, sentence in metadata['page_1'].items():
    print(f"\n{sentence_num}:")
    print(sentence)
# Out:
# === 첫 페이지 문장들 ===
#
# sentence_1:
# <ADsP  요약정리  및  오답노트>
#
# sentence_2:
# -1과목-
#
# sentence_3:
# (객관식)
#
# sentence_4:
# 데이터  마스킹  :  데이터의  속성은  유지한  채,  익명으로  생성
#
# sentence_5:
# Cinematch  ->  넷플릭스에서  개발한  알고리즘
#
# sentence_6:
# 데이터마이닝  vs  머신러닝(딥러닝)  구분하기  다른거임
#
# sentence_7:
# 트레이딩,  공급,  수요예측  ->  에너지  산업
#
# sentence_8:
# CRM  ->  고객관계관리  데이터베이스  (기업내부)
#
# sentence_9:
# ERP  ->  기업  전체를  통합적으로  관리하고  경영의  효율화  목적
#
# sentence_10:
# 빅데이터  가치측정  어려윤  이유  :  1)  데이터  재사용,재조합,다목적용  개발
#
# sentence_11:
# 2)  새로운  가치  창출
#
# sentence_12:
# 3)  분석  기술  발전
#
# sentence_13:
# cf.  전문인력증가는  가치측정과  관련  없음
#
# sentence_14:
# 사생활  침해를  막기  위한  개인정보  무작위  처리  (본래  목적  외에  사용  방지기술)  ->  난수화
#
# sentence_15:
# 유형분석  ->  특성에따라  분류할때  사용한다.
#
# sentence_16:
# 핀테크(금융)분야에서  빅데이터  활용의  핵심분야  ->  신용평가
#
# sentence_17:
# K-NN  분석기법  -  딥러닝과  관련  x
#
# sentence_18:
# LSTM,  Autoencoder,  RNN  ->  딥러닝과  관련  o
#
# sentence_19:
# Caffe,  Tnsorflow,  Theano  ->  딥러닝  관련된  오픈소스
#
# sentence_20:
# ...
